# %% [markdown]
# ### Load dataset - ProofNet

# %%
from datasets import load_dataset

# %%
test_set = load_dataset('hoskinson-center/proofnet', split='test')
vali_set = load_dataset('hoskinson-center/proofnet', split='validation')

# %%
# Column names

test_set.column_names
# Out:
# ['id', 'nl_statement', 'nl_proof', 'formal_statement', 'src_header']

# %%
test_set.data
# Out:
# MemoryMappedTable
# id: string
# nl_statement: string
# nl_proof: string
# formal_statement: string
# src_header: string
# ----
# id: [["Rudin|exercise_1_1b","Rudin|exercise_1_4","Rudin|exercise_1_8","Rudin|exercise_1_12","Rudin|exercise_1_14",...,"Dummit-Foote|exercise_9_1_10","Dummit-Foote|exercise_9_4_2a","Dummit-Foote|exercise_9_4_2c","Dummit-Foote|exercise_9_4_9","Dummit-Foote|exercise_11_1_13"]]
# ...
