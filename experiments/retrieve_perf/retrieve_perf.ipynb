# %% [markdown]
# ### all-minilm-l6-v2_w-theorem

# %%
import retrieve_perf_func as rpf

from langchain_huggingface import HuggingFaceEmbeddings

# %%
model = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=False,
                                save_loc='./all-minilm-l6-v2_w-theorem/blank_eval_template_with_theorem.csv')

corpus = rpf.get_corpus(raw_data_path=proofwiki_path,
                        only_def=False)

rpf.save_corpus_to_index(corpus=corpus,
                         embedding_model=model,
                         save_loc='./all-minilm-l6-v2_w-theorem/ref_index_with_theorem')

# %% [markdown]
# #### To only evaluate

# %%
model = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=False)

ref_index = rpf.get_index(index_loc='./all-minilm-l6-v2_w-theorem/ref_index_with_theorem',
                          embedding_model=model)

rpf.retrieval_eval(eval_df=eval_df,
                   index=ref_index,
                   save_loc='./all-minilm-l6-v2_w-theorem/all-minilm-l6-v2_w-theorem-retrieve-perf.csv')
# Out:
#       theorem_id                                     throrem_titles  \
# 10980      15893    Summation over k to n of Natural Logarithm of k
# 10981      15894  Difference between Summation of Natural Logari...
# 10982      15895  Sum over k of n Choose k by x to the k by kth ...
# 10983      15899  Summation to n of Reciprocal of k by k-1 of Ha...
# 10984      15900                      Riemann Zeta Function of 1000
# ...          ...                                                ...
# 13721      19711    Direct Product of Banach Spaces is Banach Space
# 13722      19712    Cartesian Plane Rotated with respect to Another
# 13723      19714               Dot Product of Perpendicular Vectors
# 13724      19715            Dot Product of Orthogonal Basis Vectors
# 13725      19732          Number of Terms in Homogeneous Polynomial
#
#                                         theorem_contents  \
# 10980  :$\ds \sum_{k \mathop = 1}^n \ln k = \map \ln ...
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./all-minilm-l6-v2_w-theorem/all-minilm-l6-v2_w-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.071
# MRR = 0.23
# R@3     0.093068
# R@5     0.137472
# R@10    0.217803
# R@50    0.435938
# dtype: float64

# %% [markdown]
# ### all-minilm-l6-v2_wo-theorem

# %%
import retrieve_perf_func as rpf

from langchain_huggingface import HuggingFaceEmbeddings

# %%
model = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                save_loc='./all-minilm-l6-v2_wo-theorem/blank_eval_template_without_theorem.csv')

corpus = rpf.get_corpus(raw_data_path=proofwiki_path)
rpf.save_corpus_to_index(corpus=corpus,
                         embedding_model=model,
                         save_loc='./all-minilm-l6-v2_wo-theorem/ref_index_without_theorem')

# %% [markdown]
# #### To only evaluate

# %%
model = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                save_loc='./all-minilm-l6-v2_wo-theorem/blank_eval_template_without_theorem.csv')

ref_index = rpf.get_index(index_loc='./all-minilm-l6-v2_wo-theorem/ref_index_without_theorem',
                          embedding_model=model)

rpf.retrieval_eval(eval_df=eval_df,
                   index=ref_index,
                   save_loc='./all-minilm-l6-v2_wo-theorem/all-minilm-l6-v2_wo-theorem-retrieve-perf.csv')
# Out:
#       theorem_id                                     throrem_titles  \
# 10592      15878               Lower Bound for Binomial Coefficient
# 10593      15881  Sum over k of n Choose k by p^k by (1-p)^n-k b...
# 10594      15882  Sequence of General Harmonic Numbers Converges...
# 10595      15884       Generating Function of Bernoulli Polynomials
# 10596      15885                   Symmetry of Bernoulli Polynomial
# ...          ...                                                ...
# 13235      19711    Direct Product of Banach Spaces is Banach Space
# 13236      19712    Cartesian Plane Rotated with respect to Another
# 13237      19714               Dot Product of Perpendicular Vectors
# 13238      19715            Dot Product of Orthogonal Basis Vectors
# 13239      19732          Number of Terms in Homogeneous Polynomial
#
#                                         theorem_contents  \
# 10592  Let $n, k \in \Z$ such that $n \ge k \ge 0$.Th...
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./all-minilm-l6-v2_wo-theorem/all-minilm-l6-v2_wo-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.15
# MRR = 0.53
# R@3     0.245722
# R@5     0.300509
# R@10    0.395974
# R@50    0.611787
# dtype: float64

# %% [markdown]
# ### BM25_w-theorem

# %%
from langchain_community.retrievers import BM25Retriever

import retrieve_perf_func as rpf
import pandas as pd

proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'
corpus = rpf.get_corpus(raw_data_path=proofwiki_path, only_def=False)

retriever = BM25Retriever.from_documents(documents=corpus, k=50)

eval_df = pd.read_csv('./bm25_w-theorem/blank_eval_template_with_theorem.csv').drop('Unnamed: 0', axis=1)
eval_df = eval_df.iloc[int(0.8*len(eval_df)):, :]

for args in eval_df.iterrows():
    theorem_id = args[1]['theorem_id']
    theorem_content = args[1]['theorem_contents']
    actual_refs = eval(args[1]['ref_ids'])
    
    retrieve_50 = retriever.invoke(theorem_content)
    if eval_df.loc[args[0], 'theorem_id'] in [doc.metadata['id'] for doc in retrieve_50]:
        self_index = [doc.metadata['id'] for doc in retrieve_50].index(eval_df.loc[args[0], 'theorem_id'])
        retrieve_50 = BM25Retriever.from_documents(documents=corpus, k=51).invoke(theorem_content)
        retrieve_50.pop(self_index)
    rr = 0
    
    for k in [3, 5, 10, 50]:
        retrieved_docs = list(doc.metadata['id'] for doc in retrieve_50[:k])
        intersec_K = set(actual_refs).intersection(set(retrieved_docs))
        correct_index = list(filter(lambda first_index: first_index in eval(args[1]['ref_ids']), retrieved_docs))
        
        precision_K = len(intersec_K)/k
        recall_K = len(intersec_K)/len(set(actual_refs))
        
        if k == 50 and correct_index:
            rr = 1/(retrieved_docs.index(correct_index[0]) + 1)
        
        eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
        eval_df.at[args[0], f'P@{k}'] = precision_K
        eval_df.at[args[0], f'R@{k}'] = recall_K
        eval_df.at[args[0], f'RR'] = rr
        
        if theorem_id in retrieved_docs and k == 50:
            eval_df.at[args[0], 'self_retrieve'] = True
        elif k == 50:
            eval_df.at[args[0], 'self_retrieve'] = False
    
eval_df.to_csv('./bm25_w-theorem/bm25_w-theorem-retrieve-perf.csv')
# Out:
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_67284/1513581156.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[15894, 15888, 19619]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_67284/1513581156.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[15894, 15888, 19619, 15933, 15903]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./bm25_w-theorem/bm25_w-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.023
# MRR = 0.086
# R@3     0.022833
# R@5     0.034764
# R@10    0.059545
# R@50    0.169560
# dtype: float64

# %% [markdown]
# ### BM25_wo-theorem

# %%
from langchain_community.retrievers import BM25Retriever

import retrieve_perf_func as rpf
import pandas as pd

proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'
corpus = rpf.get_corpus(raw_data_path=proofwiki_path, only_def=True)

retriever = BM25Retriever.from_documents(documents=corpus, k=50)

eval_df = pd.read_csv('./bm25_wo-theorem/blank_eval_template_without_theorem.csv').drop('Unnamed: 0', axis=1)
eval_df = eval_df.iloc[int(0.8*len(eval_df)):, :]

for args in eval_df.iterrows():
    theorem_id = args[1]['theorem_id']
    theorem_content = args[1]['theorem_contents']
    actual_refs = eval(args[1]['ref_ids'])
    
    retrieve_50 = retriever.invoke(theorem_content)
    rr = 0
    
    for k in [3, 5, 10, 50]:
        retrieved_docs = list(doc.metadata['id'] for doc in retrieve_50[:k])
        intersec_K = set(actual_refs).intersection(set(retrieved_docs))
        correct_index = list(filter(lambda first_index: first_index in eval(args[1]['ref_ids']), retrieved_docs))
        
        precision_K = len(intersec_K)/k
        recall_K = len(intersec_K)/len(set(actual_refs))
        
        if k == 50 and correct_index:
            rr = 1/(retrieved_docs.index(correct_index[0]) + 1)
        
        eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
        eval_df.at[args[0], f'P@{k}'] = precision_K
        eval_df.at[args[0], f'R@{k}'] = recall_K
        eval_df.at[args[0], f'RR'] = rr
        
        if theorem_id in retrieved_docs and k == 50:
            eval_df.at[args[0], 'self_retrieve'] = True
        elif k == 50:
            eval_df.at[args[0], 'self_retrieve'] = False
    
eval_df.to_csv('./bm25_wo-theorem/bm25_wo-theorem-retrieve-perf.csv')
# Out:
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_3324/2881996687.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[29513, 22623, 32558]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_3324/2881996687.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[29513, 22623, 32558, 25464, 32561]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./bm25_wo-theorem/bm25_wo-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.066
# MRR = 0.24
# R@3     0.085579
# R@5     0.110239
# R@10    0.158973
# R@50    0.288337
# dtype: float64

# %% [markdown]
# ### TF-IDF_w-theorem

# %%
from langchain_community.retrievers import TFIDFRetriever

import retrieve_perf_func as rpf
import pandas as pd

proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'
corpus = rpf.get_corpus(raw_data_path=proofwiki_path, only_def=False)

retriever = TFIDFRetriever.from_documents(documents=corpus, k=50)

eval_df = pd.read_csv('./tfidf_w-theorem/blank_eval_template_with_theorem.csv').drop('Unnamed: 0', axis=1)
eval_df = eval_df.iloc[int(0.8*len(eval_df)):, :]

for args in eval_df.iterrows():
    theorem_id = args[1]['theorem_id']
    theorem_content = args[1]['theorem_contents']
    actual_refs = eval(args[1]['ref_ids'])
    
    retrieve_50 = retriever.invoke(theorem_content)
    if eval_df.loc[args[0], 'theorem_id'] in [doc.metadata['id'] for doc in retrieve_50]:
        self_index = [doc.metadata['id'] for doc in retrieve_50].index(eval_df.loc[args[0], 'theorem_id'])
        retrieve_50 = TFIDFRetriever.from_documents(documents=corpus, k=51).invoke(theorem_content)
        retrieve_50.pop(self_index)
    rr = 0
    
    for k in [3, 5, 10, 50]:
        retrieved_docs = list(doc.metadata['id'] for doc in retrieve_50[:k])
        intersec_K = set(actual_refs).intersection(set(retrieved_docs))
        correct_index = list(filter(lambda first_index: first_index in eval(args[1]['ref_ids']), retrieved_docs))
        
        precision_K = len(intersec_K)/k
        recall_K = len(intersec_K)/len(set(actual_refs))
        
        if k == 50 and correct_index:
            rr = 1/(retrieved_docs.index(correct_index[0]) + 1)
        
        eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
        eval_df.at[args[0], f'P@{k}'] = precision_K
        eval_df.at[args[0], f'R@{k}'] = recall_K
        eval_df.at[args[0], f'RR'] = rr
        
        if theorem_id in retrieved_docs and k == 50:
            eval_df.at[args[0], 'self_retrieve'] = True
        elif k == 50:
            eval_df.at[args[0], 'self_retrieve'] = False

eval_df.to_csv('./tfidf_w-theorem/tfidf_w-theorem-retrieve-perf.csv')
# Out:
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_67284/2112164803.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[20058, 32908, 32624]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_67284/2112164803.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[20058, 32908, 32624, 13398, 12567]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./tfidf_w-theorem/tfidf_w-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.07
# MRR = 0.22
# R@3     0.091029
# R@5     0.134211
# R@10    0.218099
# R@50    0.481606
# dtype: float64

# %% [markdown]
# ### TF-IDF_wo-theorem

# %%
from langchain_community.retrievers import TFIDFRetriever

import retrieve_perf_func as rpf
import pandas as pd

proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'
corpus = rpf.get_corpus(raw_data_path=proofwiki_path, only_def=True)

retriever = TFIDFRetriever.from_documents(documents=corpus, k=50)

eval_df = pd.read_csv('./tfidf_wo-theorem/blank_eval_template_without_theorem.csv').drop('Unnamed: 0', axis=1)
eval_df = eval_df.iloc[int(0.8*len(eval_df)):, :]

for args in eval_df.iterrows():
    theorem_id = args[1]['theorem_id']
    theorem_content = args[1]['theorem_contents']
    actual_refs = eval(args[1]['ref_ids'])
    
    retrieve_50 = retriever.invoke(theorem_content)
    rr = 0
    
    for k in [3, 5, 10, 50]:
        retrieved_docs = list(doc.metadata['id'] for doc in retrieve_50[:k])
        intersec_K = set(actual_refs).intersection(set(retrieved_docs))
        correct_index = list(filter(lambda first_index: first_index in eval(args[1]['ref_ids']), retrieved_docs))
        
        precision_K = len(intersec_K)/k
        recall_K = len(intersec_K)/len(set(actual_refs))
        
        if k == 50 and correct_index:
            rr = 1/(retrieved_docs.index(correct_index[0]) + 1)
        
        eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
        eval_df.at[args[0], f'P@{k}'] = precision_K
        eval_df.at[args[0], f'R@{k}'] = recall_K
        eval_df.at[args[0], f'RR'] = rr
        
        if theorem_id in retrieved_docs and k == 50:
            eval_df.at[args[0], 'self_retrieve'] = True
        elif k == 50:
            eval_df.at[args[0], 'self_retrieve'] = False
    
eval_df.to_csv('./tfidf_wo-theorem/tfidf_wo-theorem-retrieve-perf.csv')
# Out:
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_3324/1431682976.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[25464, 25467, 32909]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# /var/folders/qd/2g4x2ljn7mg77q6tlqd30wf40000gn/T/ipykernel_3324/1431682976.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[25464, 25467, 32909, 30726, 32631]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   eval_df.at[args[0], f'retrieved_{k}'] = str(retrieved_docs)
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./tfidf_wo-theorem/tfidf_wo-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.15
# MRR = 0.51
# R@3     0.234795
# R@5     0.318233
# R@10    0.416682
# R@50    0.662517
# dtype: float64

# %% [markdown]
# ### Bert-Base_w-theorem

# %%
from langchain_huggingface import HuggingFaceEmbeddings

import retrieve_perf_func as rpf

model = HuggingFaceEmbeddings(model_name = 'bert-base-uncased')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=False,
                                save_loc='./bert_w-theorem/blank_eval_template_with_theorem.csv')

corpus = rpf.get_corpus(raw_data_path=proofwiki_path,
                        only_def=False)

rpf.save_corpus_to_index(corpus=corpus,
                         embedding_model=model,
                         save_loc='./bert_w-theorem/ref_index_with_theorem')
# Out:
# No sentence-transformers model found with name bert-base-uncased. Creating a new one with mean pooling.

# %%
model = HuggingFaceEmbeddings(model_name = 'bert-base-uncased')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=False)

ref_index = rpf.get_index(index_loc='./bert_w-theorem/ref_index_with_theorem',
                          embedding_model=model)

rpf.retrieval_eval(eval_df=eval_df,
                   index=ref_index,
                   save_loc='./bert_w-theorem/bert_w-theorem-retrieve-perf.csv')
# Out:
# No sentence-transformers model found with name bert-base-uncased. Creating a new one with mean pooling.
#       theorem_id                                     throrem_titles  \
# 10980      15893    Summation over k to n of Natural Logarithm of k
# 10981      15894  Difference between Summation of Natural Logari...
# 10982      15895  Sum over k of n Choose k by x to the k by kth ...
# 10983      15899  Summation to n of Reciprocal of k by k-1 of Ha...
# 10984      15900                      Riemann Zeta Function of 1000
# ...          ...                                                ...
# 13721      19711    Direct Product of Banach Spaces is Banach Space
# 13722      19712    Cartesian Plane Rotated with respect to Another
# 13723      19714               Dot Product of Perpendicular Vectors
# 13724      19715            Dot Product of Orthogonal Basis Vectors
# 13725      19732          Number of Terms in Homogeneous Polynomial
#
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./bert_w-theorem/bert_w-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.013
# MRR = 0.052
# R@3     0.014188
# R@5     0.022475
# R@10    0.034697
# R@50    0.089394
# dtype: float64

# %% [markdown]
# ### Bert-Base_wo-theorem

# %%
from langchain_huggingface import HuggingFaceEmbeddings

import retrieve_perf_func as rpf

model = HuggingFaceEmbeddings(model_name = 'bert-base-uncased')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=True,
                                save_loc='./bert_wo-theorem/blank_eval_template_without_theorem.csv')

corpus = rpf.get_corpus(raw_data_path=proofwiki_path,
                        only_def=True)

rpf.save_corpus_to_index(corpus=corpus,
                         embedding_model=model,
                         save_loc='./bert_wo-theorem/ref_index_without_theorem')
# Out:
# No sentence-transformers model found with name bert-base-uncased. Creating a new one with mean pooling.

# %%
model = HuggingFaceEmbeddings(model_name = 'bert-base-uncased')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=True)

ref_index = rpf.get_index(index_loc='./bert_wo-theorem/ref_index_without_theorem',
                          embedding_model=model)

rpf.retrieval_eval(eval_df=eval_df,
                   index=ref_index,
                   save_loc='./bert_wo-theorem/bert_wo-theorem-retrieve-perf.csv')
# Out:
# No sentence-transformers model found with name bert-base-uncased. Creating a new one with mean pooling.
#       theorem_id                                     throrem_titles  \
# 10592      15878               Lower Bound for Binomial Coefficient
# 10593      15881  Sum over k of n Choose k by p^k by (1-p)^n-k b...
# 10594      15882  Sequence of General Harmonic Numbers Converges...
# 10595      15884       Generating Function of Bernoulli Polynomials
# 10596      15885                   Symmetry of Bernoulli Polynomial
# ...          ...                                                ...
# 13235      19711    Direct Product of Banach Spaces is Banach Space
# 13236      19712    Cartesian Plane Rotated with respect to Another
# 13237      19714               Dot Product of Perpendicular Vectors
# 13238      19715            Dot Product of Orthogonal Basis Vectors
# 13239      19732          Number of Terms in Homogeneous Polynomial
#
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./bert_wo-theorem/bert_wo-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.039
# MRR = 0.16
# R@3     0.055674
# R@5     0.068570
# R@10    0.092817
# R@50    0.158266
# dtype: float64

# %% [markdown]
# ### all-minilm-l6-v2-finetune_w_theorem

# %%
import retrieve_perf_func as rpf

from langchain_huggingface import HuggingFaceEmbeddings

# %%
model = HuggingFaceEmbeddings(model_name = 'TONKKrongyuth/finetune-all-minilm-I6-v2-proofwiki_w-theorem')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=False,
                                save_loc='./all-minilm-I6-v2-finetune_w-theorem/blank_eval_template_with_theorem.csv')

corpus = rpf.get_corpus(raw_data_path=proofwiki_path,
                        only_def=False)

rpf.save_corpus_to_index(corpus=corpus,
                         embedding_model=model,
                         save_loc='./all-minilm-I6-v2-finetune_w-theorem/ref_index_with_theorem')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/31.9k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
model = HuggingFaceEmbeddings(model_name = 'TONKKrongyuth/finetune-all-minilm-I6-v2-proofwiki_w-theorem')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                only_def=False)

ref_index = rpf.get_index(index_loc='./all-minilm-I6-v2-finetune_w-theorem/ref_index_with_theorem',
                          embedding_model=model)

rpf.retrieval_eval(eval_df=eval_df,
                   index=ref_index,
                   save_loc='./all-minilm-I6-v2-finetune_w-theorem/all-minilm-I6-v2-finetune_w-theorem-retrieve-perf.csv')
# Out:
#       theorem_id                                     throrem_titles  \
# 10980      15893    Summation over k to n of Natural Logarithm of k
# 10981      15894  Difference between Summation of Natural Logari...
# 10982      15895  Sum over k of n Choose k by x to the k by kth ...
# 10983      15899  Summation to n of Reciprocal of k by k-1 of Ha...
# 10984      15900                      Riemann Zeta Function of 1000
# ...          ...                                                ...
# 13721      19711    Direct Product of Banach Spaces is Banach Space
# 13722      19712    Cartesian Plane Rotated with respect to Another
# 13723      19714               Dot Product of Perpendicular Vectors
# 13724      19715            Dot Product of Orthogonal Basis Vectors
# 13725      19732          Number of Terms in Homogeneous Polynomial
#
#                                         theorem_contents  \
# 10980  :$\ds \sum_{k \mathop = 1}^n \ln k = \map \ln ...
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./all-minilm-I6-v2-finetune_w-theorem/all-minilm-I6-v2-finetune_w-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.081
# MRR = 0.31
# R@3     0.132930
# R@5     0.178914
# R@10    0.246290
# R@50    0.414994
# dtype: float64

# %% [markdown]
# ### all-minilm-l6-v2-finetune_wo_theorem

# %%
import retrieve_perf_func as rpf

from langchain_huggingface import HuggingFaceEmbeddings

# %%
model = HuggingFaceEmbeddings(model_name = 'TONKKrongyuth/finetune-all-minilm-L6-v2-proofwiki_wo-theorem')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path,
                                save_loc='./all-minilm-I6-v2-finetune_wo-theorem/blank_eval_template_with_theorem.csv')

corpus = rpf.get_corpus(raw_data_path=proofwiki_path)

rpf.save_corpus_to_index(corpus=corpus,
                         embedding_model=model,
                         save_loc='./all-minilm-I6-v2-finetune_wo-theorem/ref_index_with_theorem')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/28.0k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
model = HuggingFaceEmbeddings(model_name = 'TONKKrongyuth/finetune-all-minilm-L6-v2-proofwiki_wo-theorem')
proofwiki_path = '/Users/ton_kkrongyuth/Senior Project/Aj.Pannapa/Prove_LLM/Data/NATURALPROOFS_DATASET/naturalproofs_proofwiki.json'

eval_df = rpf.get_eval_template(raw_data_path=proofwiki_path)

ref_index = rpf.get_index(index_loc='./all-minilm-I6-v2-finetune_wo-theorem/ref_index_with_theorem',
                          embedding_model=model)

rpf.retrieval_eval(eval_df=eval_df,
                   index=ref_index,
                   save_loc='./all-minilm-I6-v2-finetune_wo-theorem/all-minilm-I6-v2-finetune_wo-theorem-retrieve-perf.csv')
# Out:
#       theorem_id                                     throrem_titles  \
# 10592      15878               Lower Bound for Binomial Coefficient
# 10593      15881  Sum over k of n Choose k by p^k by (1-p)^n-k b...
# 10594      15882  Sequence of General Harmonic Numbers Converges...
# 10595      15884       Generating Function of Bernoulli Polynomials
# 10596      15885                   Symmetry of Bernoulli Polynomial
# ...          ...                                                ...
# 13235      19711    Direct Product of Banach Spaces is Banach Space
# 13236      19712    Cartesian Plane Rotated with respect to Another
# 13237      19714               Dot Product of Perpendicular Vectors
# 13238      19715            Dot Product of Orthogonal Basis Vectors
# 13239      19732          Number of Terms in Homogeneous Polynomial
#
#                                         theorem_contents  \
# 10592  Let $n, k \in \Z$ such that $n \ge k \ge 0$.Th...
# ...

# %%
import pandas as pd

perf_df = pd.read_csv('./all-minilm-I6-v2-finetune_wo-theorem/all-minilm-I6-v2-finetune_wo-theorem-retrieve-perf.csv')

mAP = float(perf_df[['P@3', 'P@5', 'P@10', 'P@50']].mean(axis=1).mean(axis=0))
MRR = float(perf_df['RR'].mean(axis=0))
mR = perf_df[['R@3', 'R@5', 'R@10', 'R@50']].mean(axis=0)

print(f'mAP = {mAP:.2}\nMRR = {MRR:.2}\n{mR}')
# Out:
# mAP = 0.16
# MRR = 0.72
# R@3     0.333677
# R@5     0.374305
# R@10    0.414504
# R@50    0.518618
# dtype: float64
